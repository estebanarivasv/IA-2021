# %% [markdown]
# # Análisis de Polaridad
#
# En análisis de polaridad consiste en otorgar un valor numérico (positivo o negativo) a diferentes palabras o expresiones asociadas a su uso más común con respecto a las emociones.
#
# ### Vader Sentiment Analysis
# VADER Sentiment Analysis es una herramienta de analisis de sentimiento basada en <b>reglas léxicas</b>. Funciona a partir de un conjunto de palabras o <b>lexicón</b> cuyo significado semántico está asociado mayormente a expresiones positivas o negativas. Al analizar una oración Vader tiene en cuenta todas las palabras que puedan afectar el sentimiento expresado y da como resultado un analisis del porcentaje estimado de expresiones positivas y negativas.
#
# Las palabras reconocidas por Vader tienen asociadas un <b>valor numérico</b> positivo o negativo dependiendo de la emoción que expresan. Si una palabra no se encuentra en la lista de palabras valoradas esta no se tiene en cuenta para la evaluación.
#
# Al realizar un análisis de sentimiento sobre un texto Vader devuelve 4 valores
# - Porcentaje del contenido que cae dentro de la clasificación positiva
# - Porcentaje del contenido que cae dentro de la clasificación neutral
# - Porcentaje del contenido que cae dentro de la clasificación negativa
# - Puntuación compuesta: Total de los valores obtenidos normalizado entre 1 y -1

# %%
import nltk
nltk.download('vader_lexicon')
#conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/andy/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Obtener polaridad

# %%
sentence = "This is a great product! Very good quality"
# Instanciar Analizador
sentiment_analyzer = SentimentIntensityAnalyzer()
# Analizar polaridad de la oración
analisis = sentiment_analyzer.polarity_scores(sentence)
print(analisis)
# Out:
# {'neg': 0.0, 'neu': 0.442, 'pos': 0.558, 'compound': 0.8217}

# %% [markdown]
# ## Ejemplo

# %%
import pandas as pd
df = pd.read_csv("movie-reviews.csv")
df
# Out:
#                                              reviews
# 0  Excellent movie. The acting was great and it i...
# 1               A bit boring at first but enjoyable.
# 2    Very boring. You cant tell it has a low budget.
# 3                I loved it! Best movie of the year!
# 4  The special effects looked cheap and the plot ...
# 5  The actors did a good job but the script is te...
# 6                                Boring. So boring.
# 7                     Not the worst movie I've seen
# 8                                   A waste of time

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
for index, row in df.iterrows():
    #Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row['reviews'])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    # Evaluar que valores se considerarán positivo o negativo
    if analisis['compound'] >= 0 :
        row["result"] = "Positive"
    elif analisis['compound'] <=  0 :
        row["result"] = "Negative"
    else :
        row["result"] = "Neutral"
df
# Out:
#                                              reviews negative neutral  \
# 0  Excellent movie. The acting was great and it i...        0   0.469
# 1               A bit boring at first but enjoyable.    0.157   0.476
# 2    Very boring. You cant tell it has a low budget.     0.37    0.63
# 3                I loved it! Best movie of the year!        0   0.409
# 4  The special effects looked cheap and the plot ...        0   0.803
# 5  The actors did a good job but the script is te...    0.275   0.596
# 6                                Boring. So boring.      0.83    0.17
# 7                     Not the worst movie I've seen         0   0.603
# 8                                   A waste of time     0.483   0.517
#
#   positive    result
# 0    0.531  Positive
# 1    0.367  Positive
# 2        0  Negative
# 3    0.591  Positive
# 4    0.197  Positive
# 5    0.129  Negative
# 6        0  Negative
# 7    0.397  Positive
# 8        0  Negative

# %% [markdown]
# # Ejercicio
#
# - Obtener de la API Tweets que no sean retweet y que contengan el hashtag #SpiderMan2 en inglés.
# - Realizar limpieza en los datos
# - Evaluar la polaridad

# %%
import os
from dotenv import load_dotenv
# Cargar valores del archivo .env en las variables de entorno
load_dotenv()
# Cargar valor del token a variable
bearer_token = os.environ.get("BEARER_TOKEN")
#print (bearer_token)

# %%
url = "https://api.twitter.com/2/tweets/search/recent"

# %%
params = {
    'query': '#SpiderMan2 -is:retweet',
    'tweet.fields':'created_at',
    'max_results':100
}

# %%
headers = {
    "Authorization": f"Bearer {bearer_token}",
    "User-Agent":"TweeetHunch"
}

# %%
import requests
response = requests.get(url, headers=headers, params=params)
print(response)
# Generar excepción si la respuesta no es exitosa
if response.status_code != 200:
    raise Exception(response.status_code, response.text)
print(response.json())
# Out:
# <Response [200]>
# {'data': [{'created_at': '2021-10-14T13:09:24.000Z', 'id': '1448637059623686153', 'text': '@strahzimate hello Aaron how are you today I want to present you a new suit for Peter Parker is the fusion of spidey and the CAP I hope you like it and they approve it #insomniacgames #Spiderverse  #SpidermanPS5  #SpiderMan2 🙏🏼🕷️🕷️🕷️🕷️ https://t.co/bslaAWAwns'}, {'created_at': '2021-10-14T12:06:08.000Z', 'id': '1448621138058358790', 'text': 'SPIDERMAN MOVIES RANKED #spiderman #spidermannowayhome #marvel #SpiderManPS5 #amazingspiderman #SpiderMan2 #spiderman3 #spiderverse #venom #TobeyMaguire #tomholland #andrewgarfield https://t.co/VCyD2gCAKX https://t.co/2z5km8TNgk https://t.co/RJbSudDOOp'}, {'created_at': '2021-10-14T12:04:03.000Z', 'id': '1448620617469681668', 'text': 'SPIDERMAN MOVIES RANKED #spiderman #spidermannowayhome #marvel #SpiderManPS5 #amazingspiderman #SpiderMan2 #spiderman3 #spiderverse #venom #TobeyMaguire #tomholland #andrewgarfield https://t.co/6KscRxZn1P https://t.co/V6cHDiATxt'}, {'created_at': '2021-10-14T11:34:08.000Z', 'id': '1448613085980217348', 'text': "New details about Marvel's Spider-Man 2 game leaked\n\n#SpiderMan2 #SpiderMan2Game #SpiderMan2Leaks\n\n https://t.co/3MpiKZoVQD"}, {'created_at': '2021-10-14T11:00:01.000Z', 'id': '1448604500697092099', 'text': '🕷️ Además de en su película, #Venom  será protagonista en #Spiderman2 ¿Aún no has jugado al primero? Aquí te lo contamos todo.\nhttps://t.co/Eq1KZVtYFU'}, {'created_at': '2021-10-14T09:10:21.000Z', 'id': '1448576901409243141', 'text': '#SpiderMan2 😲 https://t.co/gzQFNvKsxv'}, {'created_at': '2021-10-14T08:30:47.000Z', 'id': '1448566944513155073', 'text': 'just watched #SpiderMan2 (2004) by #SamRaimi\n\n@TobeyMaguire @kirstendunst'}, {'created_at': '2021-10-14T08:01:30.000Z', 'id': '1448559575301451779', 'text': 'Doctor Octopus, formerly Dr. Otto Gunther Octavius, is an archenemy of Spider-Man. Sometimes referred to as Doc Ock for short. He forms the Sinister Six to fight Spider-Man. #inktober2021 #DoctorOctopus #DocOck #markerdrawing #DrOttoGuntherOctavius #Spiderman2 #MarvelComics https://t.co/jgQIOeDQQM'}, {'created_at': '2021-10-14T07:17:55.000Z', 'id': '1448548606126931968', 'text': '【噂】PS5『スパイダーマン2』ピーターかマイルズ・モラレスのどちらかを選択してプレイできるように https://t.co/a0etFuDzac @gamekana さんから 面白い試みなのではないでしょうか？ #Spiderman #Spiderman2 #PS5 #Sony #Marvel #ソニー #マーベル #スパイダーマン https://t.co/BD1qzyB5Sg'}, {'created_at': '2021-10-14T06:45:39.000Z', 'id': '1448540486378180611', 'text': 'Hey @NetflixUK is #SpiderMan2 starring #TobyMaguire &amp; #AlfredMolina coming to the platform. You all the other #Spiderman films and I want to get my views in before @SpiderManMovie comes out!!! #Rewatch #SpiderManNoWayHome #Multiverse #Marvel #Sony #SpidermanSaga'}, {'created_at': '2021-10-14T03:50:36.000Z', 'id': '1448496434655813635', 'text': '@TonyTodd54 is such a legend 🌹 🌹 I seen that he’s doing Venoms voice for the #SpiderMan2 game as well. From watching him scare the shit out of me as Child in #candyman to playing one of my favorite anti-hero’s is just too great. https://t.co/n5REv77cJr'}, {'created_at': '2021-10-14T01:39:12.000Z', 'id': '1448463366805233664', 'text': "@insomniacgames Hope you guys didn't forget about my homegirl for Spider-Man 2 - one of my favorite spideys after Miles no doubt #SpiderMan2 #SpiderManPS4 #SpiderMan #SpiderGwen #GhostSpider https://t.co/DM2z0w7oRC"}, {'created_at': '2021-10-14T00:52:58.000Z', 'id': '1448451731549917184', 'text': 'Red, #SpiderMan2 is childhood for me. https://t.co/u0Uhv3YNP4'}, {'created_at': '2021-10-14T00:46:13.000Z', 'id': '1448450031300878336', 'text': '@Zerocool1000 hello shane how are you today I want to present you a new suit for Peter Parker is the fusion of spidey and the CAP I hope you like it and they approve it🙏🏼🙏🏼🙏🏼🙏🏼🕷️🕷️🕷️🕷️💪🏻💯 #SpiderMan2  #Spiderverse #insomniacgames https://t.co/muIuuWST2h'}, {'created_at': '2021-10-14T00:44:03.000Z', 'id': '1448449486863360002', 'text': '@shanemccloskey_ hello shane how are you today I want  ...

# %%
import pandas as pd
import re, string
df = pd.json_normalize(response.json()['data'])
df
# Out:
#                   created_at                   id  \
# 0   2021-10-14T13:09:24.000Z  1448637059623686153
# 1   2021-10-14T12:06:08.000Z  1448621138058358790
# 2   2021-10-14T12:04:03.000Z  1448620617469681668
# 3   2021-10-14T11:34:08.000Z  1448613085980217348
# 4   2021-10-14T11:00:01.000Z  1448604500697092099
# ..                       ...                  ...
# 95  2021-10-13T02:37:28.000Z  1448115643895615489
# 96  2021-10-13T02:36:49.000Z  1448115477432111113
# 97  2021-10-13T02:35:47.000Z  1448115218761011203
# 98  2021-10-13T02:34:38.000Z  1448114930423586822
# 99  2021-10-13T02:34:19.000Z  1448114848726872069
#
#                                                  text
# 0   @strahzimate hello Aaron how are you today I w...
# 1   SPIDERMAN MOVIES RANKED #spiderman #spidermann...
# 2   SPIDERMAN MOVIES RANKED #spiderman #spidermann...
# 3   New details about Marvel's Spider-Man 2 game l...
# 4   🕷️ Además de en su película, #Venom  será prot...
# ..                                                ...
# 95  “You have a train to catch…”\n\n#SpiderMan2 #Q...
# 96  One of the greatest fight scenes of all time #...
# 97  And thus begins the iconic train scene 🕷🐙 #Spi...
# 98  One more time for the people in the back! Spid...
# 99  HE’S BACK!!!! ❤️🕸🕷💙 #SpiderMan2 #QuarentineWat...
#
# [100 rows x 3 columns]

# %%
URL_REGEX = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
MENTIONS_REGEX = r"(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9-_]+)"
HASHTAG_REGEX = r"#"



df["text"].replace(URL_REGEX,'',regex=True, inplace = True)
df["text"].replace(MENTIONS_REGEX,'',regex=True, inplace = True)
df["text"].replace(HASHTAG_REGEX,'',regex=True, inplace = True)
df["text"].replace(r"[^A-Za-z0-9 | \n]+",' ',regex=True, inplace = True)
df["text"].replace(r"\t",' ',regex=True, inplace = True)
df["text"].replace('[{}]'.format(string.punctuation),' ',regex=True, inplace = True)


df["text"] = df["text"].str.lower()

df
# Out:
#                      id                                               text
# 0   1448637059623686153   hello aaron how are you today i want to prese...
# 1   1448621138058358790  spiderman movies ranked spiderman spidermannow...
# 2   1448620617469681668  spiderman movies ranked spiderman spidermannow...
# 3   1448613085980217348  new details about marvel s spider man 2 game l...
# 4   1448604500697092099    adem s de en su pel cula  venom  ser  protag...
# ..                  ...                                                ...
# 95  1448115643895615489   you have a train to catch \n\nspiderman2 quar...
# 96  1448115477432111113  one of the greatest fight scenes of all time s...
# 97  1448115218761011203  and thus begins the iconic train scene   spide...
# 98  1448114930423586822  one more time for the people in the back  spid...
# 99  1448114848726872069      he s back    spiderman2 quarentinewatchparty
#
# [100 rows x 2 columns]

# %%
df = df.drop('id', 1)

# %% [markdown]
# # Tokenización

# %%
from nltk.tokenize import TweetTokenizer
# Instanciar Tokenizer
tt = TweetTokenizer()
# Aplicar Tokenizer a la columna
tokenized_text = df['text'].apply(tt.tokenize)
df["tokenized_text"] = tokenized_text
df
# Out:
#                                                  text  \
# 0    hello aaron how are you today i want to prese...
# 1   spiderman movies ranked spiderman spidermannow...
# 2   spiderman movies ranked spiderman spidermannow...
# 3   new details about marvel s spider man 2 game l...
# 4     adem s de en su pel cula  venom  ser  protag...
# ..                                                ...
# 95   you have a train to catch \n\nspiderman2 quar...
# 96  one of the greatest fight scenes of all time s...
# 97  and thus begins the iconic train scene   spide...
# 98  one more time for the people in the back  spid...
# 99      he s back    spiderman2 quarentinewatchparty
#
#                                        tokenized_text
# 0   [hello, aaron, how, are, you, today, i, want, ...
# 1   [spiderman, movies, ranked, spiderman, spiderm...
# 2   [spiderman, movies, ranked, spiderman, spiderm...
# 3   [new, details, about, marvel, s, spider, man, ...
# 4   [adem, s, de, en, su, pel, cula, venom, ser, p...
# ..                                                ...
# 95  [you, have, a, train, to, catch, spiderman, 2,...
# 96  [one, of, the, greatest, fight, scenes, of, al...
# 97  [and, thus, begins, the, iconic, train, scene,...
# 98  [one, more, time, for, the, people, in, the, b...
# 99  [he, s, back, spiderman, 2, quarentinewatchparty]
#
# [100 rows x 2 columns]

# %%
df["negative"] = ""
df["neutral"] = ""
df["positive"] = ""
df["result"] = ""
df["compound"] = ""
for index, row in df.iterrows():
    #Analizar cada review
    analisis = sentiment_analyzer.polarity_scores(row['text'])
    row["negative"] = analisis["neg"]
    row["neutral"] = analisis["neu"]
    row["positive"] = analisis["pos"]
    row["compound"] = analisis["compound"]
    # Evaluar que valores se considerarán positivo o negativo
    
    if analisis['compound'] >= 0.5 and analisis['compound'] <= 1:
        row["result"] = "Positive"
        
    elif analisis['compound'] <= 0:
        row["result"] = "Negative"
        
    else :
        row["result"] = "Neutral"

df
# Out:
#                                                  text negative neutral  \
# 0    hello aaron how are you today i want to prese...        0   0.839
# 1   spiderman movies ranked spiderman spidermannow...        0   0.833
# 2   spiderman movies ranked spiderman spidermannow...        0   0.833
# 3   new details about marvel s spider man 2 game l...    0.143   0.683
# 4     adem s de en su pel cula  venom  ser  protag...    0.087   0.913
# ..                                                ...      ...     ...
# 95   you have a train to catch \n\nspiderman2 quar...        0       1
# 96  one of the greatest fight scenes of all time s...    0.165    0.57
# 97  and thus begins the iconic train scene   spide...        0       1
# 98  one more time for the people in the back  spid...        0       1
# 99      he s back    spiderman2 quarentinewatchparty         0       1
#
#    positive    result compound
# 0     0.161  Positive   0.6908
# 1     0.167   Neutral   0.4215
# 2     0.167   Neutral   0.4215
# 3     0.174   Neutral    0.128
# 4         0  Negative   -0.296
# ..      ...       ...      ...
# 95        0  Negative        0
# 96    0.266   Neutral   0.3818
# 97        0  Negative        0
# 98        0  Negative        0
# 99        0  Negative        0
#
# [100 rows x 6 columns]

# %%
import nltk
nltk.download('vader_lexicon')
#conda install -c conda-forge vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/agustin/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#export
df.to_csv('polarity')
