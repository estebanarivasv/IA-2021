# %%
import os
from dotenv import load_dotenv
from nltk.tokenize import TweetTokenizer
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

load_dotenv()

bearer_token = os.environ.get("BEARER_TOKEN")

# %%
dd = pd.read_csv("tweets_apple_event.csv")
dd


tt = TweetTokenizer()

tokenized_text = dd['text'].apply(tt.tokenize)
dd['tokenized_text'] = tokenized_text
dd
# Out:
#        Unnamed: 0  Unnamed: 0.1                   id  \
# 0               0             0  1450596733201813513
# 1               1             1  1450596634358808576
# 2               2             2  1450596597436350468
# 3               3             3  1450595973575716869
# 4               4             4  1450595520435609606
# ...           ...           ...                  ...
# 20053       20053            94  1450154292380274696
# 20054       20054            95  1450154291075985411
# 20055       20055            96  1450154290274881537
# 20056       20056            97  1450154289578627072
# 20057       20057            98  1450154289565945862
#
#                                                     text  \
# 0      How to get a Tesla for FREE 🚗👀\n\n#Bitcoin #HE...
# 1      Escucha 🎧🥰🔥💔💦\n#Biblia #Jesus\n#RicardoClaureP...
# 2      No te pierdas este hermoso 💌\n\n#Biblia #Jesus...
# 3      New MacBook Pro\n\n-14.2"/16.2" Liquid Retina ...
# 4      #AppleEvent maybe Apple can be bold and implem...
# ...                                                  ...
# 20053  Apple making everything thick again . 1st ipho...
# 20054  Macs officially have 120hz promotion displays....
# 20055  Soo i really saved up the last 4 years to get ...
# 20056  120Hz - Pro Motion refresh rate available for ...
# 20057                     RIP M1 Macbook Pro #AppleEvent
#
#                                           tokenized_text
# 0      [How, to, get, a, Tesla, for, FREE, 🚗, 👀, #Bit...
# 1      [Escucha, 🎧, 🥰, 🔥, 💔, 💦, #Biblia, #Jesus, #Ric...
# 2      [No, te, pierdas, este, hermoso, 💌, #Biblia, #...
# 3      [New, MacBook, Pro, -14.2, ", /, 16.2, ", Liqu...
# 4      [#AppleEvent, maybe, Apple, can, be, bold, and...
# ...                                                  ...
# 20053  [Apple, making, everything, thick, again, ., 1...
# 20054  [Macs, officially, have, 120hz, promotion, dis...
# 20055  [Soo, i, really, saved, up, the, last, 4, year...
# 20056  [120Hz, -, Pro, Motion, refresh, rate, availab...
# 20057               [RIP, M1, Macbook, Pro, #AppleEvent]
#
# [20058 rows x 5 columns]

# %%
from nltk.probability import FreqDist

tokenized_list = dd.explode('tokenized_text')
# Obtener frecuencia de cada término
fdist = FreqDist(tokenized_list['tokenized_text'])
# Convertir a dataframe
df_fdist = pd.DataFrame.from_dict(fdist, orient='index')
df_fdist.columns = ['Frequency']
df_fdist.index.name = 'Term'
df_fdist.sort_values(by=['Frequency'], inplace=True)
df_fdist

# %%
wordcloud = WordCloud(max_words=100, background_color="white").generate(dd['tokenized_text'].to_string())

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.rcParams['figure.figsize'] = [350, 350]
plt.show()
